# %% [markdown]
# # Uploading csv data from my notebook to google drive

# %%
import io
import os
import googleapiclient
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'comments.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/comments.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60755%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=DqylRxY6HrZRL82Qli0rFVKOT3PHEW&access_type=offline
# File ID: 1udgtEtByRgeaiMHUg5EWqOHdtgqUWHD-

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'post_history.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/post_history.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60783%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=6U8E2bfjBeAggk0iqU1tdM6t1s9J4F&access_type=offline
# File ID: 1eZOj1mO14iKT-nzwqV8_i3xCDrul442B

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'post_links.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/post_links.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60800%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=n4aOgLFiXhJtB8h4MH5djCrGLYbFLp&access_type=offline
# File ID: 195I3y2fPn1ES_v-e6wxl1w5YAHMoM5Q8

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'posts_answers.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/posts_answers.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60813%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=9S2yB5acM7F3RXVMgZIuh9xMrbfbr2&access_type=offline
# File ID: 1wt1s00MIcbnLetcwDjCE27FbWqTJWcmK

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'posts_questions.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/posts_questions.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60841%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=TVC1c9osY2bMOwWUZGYjGxrHAeCQwZ&access_type=offline
# File ID: 1rDcQhUGzkD28Txbv7gB2snI1c74_7Aj4

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'tags.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/tags.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60855%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=vE7Tp4bvF9ukQQLcH4jB6msi8ffbN9&access_type=offline
# File ID: 19cHTljO-AFbG4y3-sA5UoWWuNPHBKXWN

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'users.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/users.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60870%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=k6zhb0SbeWOHXI4sjHr6RHr0efGLZ9&access_type=offline
# File ID: 1bVG74W9JF9w7U95uVqrWQluhnjs6ifyR

# %%
from googleapiclient.http import MediaIoBaseUpload

# %%
import io
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive']

creds = None
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
if creds and creds.expired and creds.refresh_token:
    creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file(
        'client_secrets.json', SCOPES)
    creds = flow.run_local_server(port=0)
with open('token.json', 'w') as token:
    token.write(creds.to_json())

# Set the ID of the folder you want to upload the file to
folder_id = '1KDmKD807Tlxdr2m-Kls4UFoO0oicO0th'

# Set the name of the file you want to upload
file_name = 'badges.json'

# Set the path to the file you want to upload
file_path = '/Users/izabellamartirosyan/Desktop/Capstone/data/badges.json'

# Authenticate and build the Drive API client
creds = Credentials.from_authorized_user_file('token.json', SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

# Create a file metadata object for the JSON file
file_metadata = {
    'name': file_name,
    'parents': [folder_id],
    'mimeType': 'application/json'
}

# Create a media object for the JSON file
file_media = io.BytesIO(open(file_path, 'rb').read())

# Upload the JSON file to Google Drive
try:
    file = drive_service.files().create(
        body=file_metadata,
        media_body=googleapiclient.http.MediaIoBaseUpload(file_media, mimetype='application/json'),
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

except HttpError as error:
    print(f'An error occurred: {error}')
    file = None

# Delete the media object to free up memory
del file_media
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=854901581871-qbrcoe2unfa7irifmu621a0ki5biktle.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60881%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=o3UqiwhFfFAxcR3mYn3Ch4y1GG3mMI&access_type=offline
# File ID: 1TE5I_Xoi5IKnvW5hiaHnKpfz86fHUc3H
